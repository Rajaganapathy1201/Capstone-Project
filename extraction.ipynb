# %%
# %pip install pandas

import pandas as pd
import json
import os
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gitpython

import os

# Set the git executable environment variable before importing git
os.environ["GIT_PYTHON_GIT_EXECUTABLE"] = r"C:\Program Files\Git\bin\git.exe"

import git

# Refresh gitpython to use the specified git executable
git.refresh()

repo_url = "https://github.com/PhonePe/pulse.git"
destination_path = r"C:/Ganapathy/Capstone-Project/data"
git.Repo.clone_from(repo_url, destination_path)
print("Repository cloned successfully.")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# Cell In[44], line 15
#      13 repo_url = "https://github.com/PhonePe/pulse.git"
#      14 destination_path = r"C:/Ganapathy/Capstone-Project/data"
# ---> 15 git.Repo.clone_from(repo_url, destination_path)
#      16 print("Repository cloned successfully.")
#
# File c:\Users\Karthikeyan\AppData\Local\Programs\Python\Python313\Lib\site-packages\git\repo\base.py:1543, in Repo.clone_from(cls, url, to_path, progress, env, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1541 if env is not None:
#    1542     git.update_environment(**env)
# -> 1543 return cls._clone(
#    1544     git,
#    1545     url,
#    1546     to_path,
#    1547     GitCmdObjectDB,
#    1548     progress,
#    1549     multi_options,
# ...

# %%
import git

# %%
repo_url = "https://github.com/PhonePe/pulse.git"
destination_path = r"F:/Datascience Projects/Capstone Project/data"
git.Repo.clone_from(repo_url, destination_path)
print("Repository cloned successfully.")

# %%
import pandas as pd
import json
import os

# %%
path="C:/Ganapathy/Capstone-Project/data/data/aggregated/transaction/country/india/state"
Agg_state_list= os.listdir(path)
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm={'State':[], 'Year':[],'Quarter':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i = os.path.join(path, i) + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)
Agg_Trans
# Out:
#                           State  Year  Quarter           Transacion_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 5029                west-bengal  2024        4         Merchant payments
# 5030                west-bengal  2024        4     Peer-to-peer payments
# 5031                west-bengal  2024        4  Recharge & bill payments
# 5032                west-bengal  2024        4        Financial Services
# 5033                west-bengal  2024        4                    Others
#
#       Transacion_count  Transacion_amount
# 0                 4200       1.845307e+06
# ...

# %%
path="C:/Ganapathy/Capstone-Project/data/data/aggregated/user/country/india/state"
Agg_user_list= os.listdir(path)
Agg_user_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm_user = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Device_Brand': [],
    'User_Count': [],
    'User_Percentage': [],
    'Total_Registered_Users': [],
    'App_Opens': []
}

for i in Agg_user_list:
    p_i = os.path.join(path, i) + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = p_j + k
            Data = open(p_k, 'r')
            D = json.load(Data)
            try:
                total_users = D['data']['aggregated']['registeredUsers']
                app_opens = D['data']['aggregated']['appOpens']
                for z in D['data']['usersByDevice']:
                    brand = z['brand']
                    count = z['count']
                    percentage = z['percentage']
                    
                    clm_user['Device_Brand'].append(brand)
                    clm_user['User_Count'].append(count)
                    clm_user['User_Percentage'].append(percentage)
                    clm_user['Total_Registered_Users'].append(total_users)
                    clm_user['App_Opens'].append(app_opens)
                    clm_user['State'].append(i)
                    clm_user['Year'].append(j)
                    clm_user['Quarter'].append(int(k.strip('.json')))
            except:
                continue

# Create DataFrame
User_Device_df = pd.DataFrame(clm_user)
User_Device_df
# Out:
#                           State  Year  Quarter Device_Brand  User_Count  \
# 0     andaman-&-nicobar-islands  2018        1       Xiaomi        1665
# 1     andaman-&-nicobar-islands  2018        1      Samsung        1445
# 2     andaman-&-nicobar-islands  2018        1         Vivo         982
# 3     andaman-&-nicobar-islands  2018        1         Oppo         501
# 4     andaman-&-nicobar-islands  2018        1      OnePlus         332
# ...                         ...   ...      ...          ...         ...
# 6727                west-bengal  2022        1       Lenovo      330017
# 6728                west-bengal  2022        1      Infinix      284678
# 6729                west-bengal  2022        1         Asus      280347
# 6730                west-bengal  2022        1        Apple      277752
# 6731                west-bengal  2022        1       Others     2196334
#
#       User_Percentage  Total_Registered_Users  App_Opens
# ...

# %%
Agg_Trans

# %%
User_Device_df

# %%
path="C:/Ganapathy/Capstone-Project/data/data/aggregated/insurance/country/india/state"
Agg_insurance_list= os.listdir(path)
Agg_insurance_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm_transaction = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Transaction_Name': [],
    'Transaction_Type': [],
    'Transaction_Count': [],
    'Transaction_Amount': [],
    'From_Date': [],
    'To_Date': []
}

for i in Agg_user_list:
    p_i = os.path.join(path, i) + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j) + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = os.path.join(p_j, k)
            try:
                with open(p_k, 'r') as Data:
                    D = json.load(Data)

                from_date = D['data']['from']
                to_date = D['data']['to']

                for tx in D['data']['transactionData']:
                    tx_name = tx['name']
                    for pi in tx['paymentInstruments']:
                        tx_type = pi['type']
                        tx_count = pi['count']
                        tx_amount = pi['amount']

                        clm_transaction['State'].append(i)
                        clm_transaction['Year'].append(j)
                        clm_transaction['Quarter'].append(int(k.strip('.json')))
                        clm_transaction['Transaction_Name'].append(tx_name)
                        clm_transaction['Transaction_Type'].append(tx_type)
                        clm_transaction['Transaction_Count'].append(tx_count)
                        clm_transaction['Transaction_Amount'].append(tx_amount)
                        clm_transaction['From_Date'].append(from_date)
                        clm_transaction['To_Date'].append(to_date)

            except:
                continue

# Create DataFrame
Transaction_df = pd.DataFrame(clm_transaction)
Transaction_df
# Out:
#                          State  Year  Quarter Transaction_Name  \
# 0    andaman-&-nicobar-islands  2020        2        Insurance
# 1    andaman-&-nicobar-islands  2020        3        Insurance
# 2    andaman-&-nicobar-islands  2020        4        Insurance
# 3    andaman-&-nicobar-islands  2021        1        Insurance
# 4    andaman-&-nicobar-islands  2021        2        Insurance
# ..                         ...   ...      ...              ...
# 677                west-bengal  2023        4        Insurance
# 678                west-bengal  2024        1        Insurance
# 679                west-bengal  2024        2        Insurance
# 680                west-bengal  2024        3        Insurance
# 681                west-bengal  2024        4        Insurance
#
#     Transaction_Type  Transaction_Count  Transaction_Amount      From_Date  \
# 0              TOTAL                  6              1360.0  1585679400000
# ...

# %%
path="C:/Ganapathy/Capstone-Project/data/data/map/transaction/hover/country/india/state"
Map_Transaction_list= os.listdir(path)
Map_Transaction_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm_summary = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Transaction_Type': [],
    'Transaction_Count': [],
    'Transaction_Amount': []
}

for i in Agg_user_list:
    p_i = os.path.join(path, i) + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j) + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = os.path.join(p_j, k)
            try:
                with open(p_k, 'r') as Data:
                    D = json.load(Data)

                for entry in D['data']['hoverDataList']:
                    state_name = entry['name']
                    for metric in entry['metric']:
                        tx_type = metric['type']
                        tx_count = metric['count']
                        tx_amount = metric['amount']

                        clm_summary['State'].append(state_name.title())  # Title case for consistency
                        clm_summary['Year'].append(j)
                        clm_summary['Quarter'].append(int(k.strip('.json')))
                        clm_summary['Transaction_Type'].append(tx_type)
                        clm_summary['Transaction_Count'].append(tx_count)
                        clm_summary['Transaction_Amount'].append(tx_amount)

            except:
                continue

# Create DataFrame
State_Transactions_df = pd.DataFrame(clm_summary)
State_Transactions_df
# Out:
#                                    State  Year  Quarter Transaction_Type  \
# 0      North And Middle Andaman District  2018        1            TOTAL
# 1                 South Andaman District  2018        1            TOTAL
# 2                      Nicobars District  2018        1            TOTAL
# 3      North And Middle Andaman District  2018        2            TOTAL
# 4                 South Andaman District  2018        2            TOTAL
# ...                                  ...   ...      ...              ...
# 20599                Alipurduar District  2024        4            TOTAL
# 20600         Paschim Bardhaman District  2024        4            TOTAL
# 20601                     Nadia District  2024        4            TOTAL
# 20602                   Birbhum District  2024        4            TOTAL
# 20603           Purba Medinipur District  2024        4            TOTAL
#
#        Transaction_Count  Transaction_Amount
# 0                    442        9.316631e+05
# ...

# %%
path="C:/Ganapathy/Capstone-Project/data/data/map/user/hover/country/india/state"
Map_User_list= os.listdir(path)
Map_User_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm_hover_user = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Registered_Users': [],
    'App_Opens': []
}

for i in Agg_user_list:
    p_i = os.path.join(path, i) + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j) + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = os.path.join(p_j, k)
            try:
                with open(p_k, 'r') as Data:
                    D = json.load(Data)

                hover_data = D['data']['hoverData']

                for state, metrics in hover_data.items():
                    clm_hover_user['State'].append(state.title())
                    clm_hover_user['Year'].append(j)
                    clm_hover_user['Quarter'].append(int(k.strip('.json')))
                    clm_hover_user['Registered_Users'].append(metrics.get('registeredUsers', 0))
                    clm_hover_user['App_Opens'].append(metrics.get('appOpens', 0))

            except:
                continue

# Create DataFrame
Hover_User_df = pd.DataFrame(clm_hover_user)
Hover_User_df
# Out:
#                                    State  Year  Quarter  Registered_Users  \
# 0      North And Middle Andaman District  2018        1               632
# 1                 South Andaman District  2018        1              5846
# 2                      Nicobars District  2018        1               262
# 3      North And Middle Andaman District  2018        2               911
# 4                 South Andaman District  2018        2              8143
# ...                                  ...   ...      ...               ...
# 20603                Alipurduar District  2024        4            475688
# 20604         Paschim Bardhaman District  2024        4           1468252
# 20605                     Nadia District  2024        4           1861738
# 20606                   Birbhum District  2024        4           1114220
# 20607           Purba Medinipur District  2024        4           1717074
#
#        App_Opens
# 0              0
# 1              0
# 2              0
# ...

# %%
path="C:/Ganapathy/Capstone-Project/data/data/map/insurance/hover/country/india/state"
Map_ins_hover_list= os.listdir(path)
Map_ins_hover_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm_insurance = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Transaction_Type': [],
    'Transaction_Count': [],
    'Transaction_Amount': []
}

for i in Agg_user_list:
    p_i = os.path.join(path, i) + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j) + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = os.path.join(p_j, k)
            try:
                with open(p_k, 'r') as Data:
                    D = json.load(Data)

                for entry in D['data']['hoverDataList']:
                    state_name = entry['name']
                    for metric in entry['metric']:
                        tx_type = metric['type']
                        tx_count = metric['count']
                        tx_amount = metric['amount']

                        clm_insurance['State'].append(state_name.title())
                        clm_insurance['Year'].append(j)
                        clm_insurance['Quarter'].append(int(k.strip('.json')))
                        clm_insurance['Transaction_Type'].append(tx_type)
                        clm_insurance['Transaction_Count'].append(tx_count)
                        clm_insurance['Transaction_Amount'].append(tx_amount)

            except:
                continue

# Create DataFrame
Insurance_Transactions_df = pd.DataFrame(clm_insurance)
Insurance_Transactions_df
# Out:
#                                    State  Year  Quarter Transaction_Type  \
# 0                 South Andaman District  2020        2            TOTAL
# 1                      Nicobars District  2020        2            TOTAL
# 2      North And Middle Andaman District  2020        3            TOTAL
# 3                 South Andaman District  2020        3            TOTAL
# 4                      Nicobars District  2020        3            TOTAL
# ...                                  ...   ...      ...              ...
# 13871                Alipurduar District  2024        4            TOTAL
# 13872         Paschim Bardhaman District  2024        4            TOTAL
# 13873                     Nadia District  2024        4            TOTAL
# 13874                   Birbhum District  2024        4            TOTAL
# 13875           Purba Medinipur District  2024        4            TOTAL
#
#        Transaction_Count  Transaction_Amount
# 0                      3               795.0
# ...

# %%
path="C:/Ganapathy/Capstone-Project/data/data/top/user/country/india/state"
Top_user_list= os.listdir(path)
Top_user_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Level': [],          # 'State', 'District', or 'Pincode'
    'Entity_Name': [],    # name of state/district/pincode
    'Registered_Users': []
}

for i in Top_user_list:
    p_i = os.path.join(path, i) + "/"
    Top_yr = os.listdir(p_i)
    for j in Top_yr:
        p_j = p_i + j + "/"
        Top_yr_list = os.listdir(p_j)
        for k in Top_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as d:
                Data = json.load(d)
                for level in ['states', 'districts', 'pincodes']:
                    entries = Data['data'].get(level, [])
                    if entries is not None:
                        for entry in entries:
                            clm['Level'].append(level[:-1].title())  # State, District, Pincode
                            clm['Entity_Name'].append(entry.get('name', '').title())
                            clm['Registered_Users'].append(entry.get('registeredUsers', 0))
                            clm['State'].append(i)
                            clm['Year'].append(j)
                            clm['Quarter'].append(int(k.strip('.json')))

Top_User_df = pd.DataFrame(clm)
Top_User_df
# Out:
#                            State  Year  Quarter     Level  \
# 0      andaman-&-nicobar-islands  2018        1  District
# 1      andaman-&-nicobar-islands  2018        1  District
# 2      andaman-&-nicobar-islands  2018        1  District
# 3      andaman-&-nicobar-islands  2018        1   Pincode
# 4      andaman-&-nicobar-islands  2018        1   Pincode
# ...                          ...   ...      ...       ...
# 18291                west-bengal  2024        4   Pincode
# 18292                west-bengal  2024        4   Pincode
# 18293                west-bengal  2024        4   Pincode
# 18294                west-bengal  2024        4   Pincode
# 18295                west-bengal  2024        4   Pincode
#
#                     Entity_Name  Registered_Users
# 0                 South Andaman              5846
# 1      North And Middle Andaman               632
# 2                      Nicobars               262
# 3                        744103              1608
# ...

# %%
path="C:/Ganapathy/Capstone-Project/data/data/top/transaction/country/india/state"
Top_trans_list= os.listdir(path)
Top_trans_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Level': [],          # 'State', 'District', or 'Pincode'
    'Entity_Name': [],    # Name of state/district/pincode
    'Transaction_type': [],
    'Transaction_count': [],
    'Transaction_amount': []
}

for i in Top_trans_list:
    p_i = os.path.join(path, i) + "/"
    Top_yr = os.listdir(p_i)
    for j in Top_yr:
        p_j = p_i + j + "/"
        Top_yr_list = os.listdir(p_j)
        for k in Top_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as d:
                Data = json.load(d)
                for level in ['states', 'districts', 'pincodes']:
                    entries = Data['data'].get(level, [])
                    if entries is not None:
                        for entry in entries:
                            metric = entry.get('metric', {})
                            clm['Level'].append(level[:-1].title())  # State, District, Pincode
                            entity_name = entry.get('entityName', '')
                            if entity_name is not None:
                                clm['Entity_Name'].append(str(entity_name).title())
                            else:
                                clm['Entity_Name'].append('')
                            clm['Transaction_type'].append(metric.get('type', ''))
                            clm['Transaction_count'].append(metric.get('count', 0))
                            clm['Transaction_amount'].append(metric.get('amount', 0))
                            clm['State'].append(i)
                            clm['Year'].append(j)
                            clm['Quarter'].append(int(k.strip('.json')))

Top_Trans_df = pd.DataFrame(clm)
Top_Trans_df
# Out:
#                            State  Year  Quarter     Level  \
# 0      andaman-&-nicobar-islands  2018        1  District
# 1      andaman-&-nicobar-islands  2018        1  District
# 2      andaman-&-nicobar-islands  2018        1  District
# 3      andaman-&-nicobar-islands  2018        1   Pincode
# 4      andaman-&-nicobar-islands  2018        1   Pincode
# ...                          ...   ...      ...       ...
# 18290                west-bengal  2024        4   Pincode
# 18291                west-bengal  2024        4   Pincode
# 18292                west-bengal  2024        4   Pincode
# 18293                west-bengal  2024        4   Pincode
# 18294                west-bengal  2024        4   Pincode
#
#                     Entity_Name Transaction_type  Transaction_count  \
# 0                 South Andaman            TOTAL               5688
# 1                      Nicobars            TOTAL                528
# ...

# %%
path="C:/Ganapathy/Capstone-Project/data/data/top/insurance/country/india/state"
Top_ins_list= os.listdir(path)
Top_ins_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Level': [],           # 'State', 'District', or 'Pincode'
    'Entity_Name': [],     # Name of state/district/pincode
    'Insurance_type': [],  # Usually 'TOTAL' based on your data
    'Insurance_count': [], 
    'Insurance_amount': []
}

for i in Top_ins_list:  # Use the correct insurance directory list
    p_i = os.path.join(path, i) + "/"
    Top_yr = os.listdir(p_i)
    for j in Top_yr:
        p_j = p_i + j + "/"
        Top_yr_list = os.listdir(p_j)
        for k in Top_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as d:
                Data = json.load(d)
                for level in ['states', 'districts', 'pincodes']:
                    entries = Data['data'].get(level, [])
                    if entries is not None:
                        for entry in entries:
                            metric = entry.get('metric', {})
                            clm['Level'].append(level[:-1].title())  # State, District, Pincode
                            entity_name = entry.get('entityName', '')
                            if entity_name is not None:
                                clm['Entity_Name'].append(str(entity_name).title())
                            else:
                                clm['Entity_Name'].append('')
                            clm['Insurance_type'].append(metric.get('type', ''))
                            clm['Insurance_count'].append(metric.get('count', 0))
                            clm['Insurance_amount'].append(metric.get('amount', 0))
                            clm['State'].append(i)
                            clm['Year'].append(j)
                            clm['Quarter'].append(int(k.strip('.json')))

Top_Insurance_df = pd.DataFrame(clm)
Top_Insurance_df
# Out:
#                            State  Year  Quarter     Level    Entity_Name  \
# 0      andaman-&-nicobar-islands  2020        2  District       Nicobars
# 1      andaman-&-nicobar-islands  2020        2  District  South Andaman
# 2      andaman-&-nicobar-islands  2020        2   Pincode         744301
# 3      andaman-&-nicobar-islands  2020        2   Pincode         744104
# 4      andaman-&-nicobar-islands  2020        2   Pincode         744101
# ...                          ...   ...      ...       ...            ...
# 12271                west-bengal  2024        4   Pincode         711101
# 12272                west-bengal  2024        4   Pincode         700091
# 12273                west-bengal  2024        4   Pincode         700150
# 12274                west-bengal  2024        4   Pincode         700039
# 12275                west-bengal  2024        4   Pincode         700156
#
#       Insurance_type  Insurance_count  Insurance_amount
# ...

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SQLAlchemy PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Vinayak12345@localhost:3306/phonepe")

# %%
# !pip install cryptography
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\Karthikeyan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Create the table if it does not exist, or replace it if it does
Agg_Trans.to_sql(name='agg_trans', con=engine, if_exists='append', index=False)
# Out:
# 5034

# %%
User_Device_df.to_sql(name='User_Device_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\3403129913.py:1: UserWarning:
#
# The provided table name 'User_Device_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 6732

# %%
Transaction_df.to_sql(name='Transaction_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\885382035.py:1: UserWarning:
#
# The provided table name 'Transaction_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 682

# %%
State_Transactions_df.to_sql(name='State_Transactions_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\1278373825.py:1: UserWarning:
#
# The provided table name 'State_Transactions_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 20604

# %%
Hover_User_df.to_sql(name='Hover_User_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\2435105426.py:1: UserWarning:
#
# The provided table name 'Hover_User_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 20608

# %%
Insurance_Transactions_df.to_sql(name='Insurance_Transactions_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\292300590.py:1: UserWarning:
#
# The provided table name 'Insurance_Transactions_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 13876

# %%
Top_User_df.to_sql(name='Top_User_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\560462696.py:1: UserWarning:
#
# The provided table name 'Top_User_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 18296

# %%
Top_Trans_df.to_sql(name='Top_Trans_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\1923715414.py:1: UserWarning:
#
# The provided table name 'Top_Trans_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 18295

# %%
Top_Insurance_df.to_sql(name='Top_Insurance_df', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\Karthikeyan\AppData\Local\Temp\ipykernel_21188\2761871301.py:1: UserWarning:
#
# The provided table name 'Top_Insurance_df' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# 12276

# %%
# %pip install streamlit

import streamlit as st
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nbformat>=4.2.0
# %pip install plotly

import nbformat
import pandas as pd
import plotly.express as px
import requests

# Load the GeoJSON for Indian states
geojson_url = "https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson"
india_states_geojson = requests.get(geojson_url).json()

# Ensure Top_User_df is defined before proceeding
if 'Top_User_df' not in globals():
    raise NameError("Top_User_df is not defined. Please run the cell that creates Top_User_df before running this cell.")

# Group by state and sum registered users (latest or total)
state_user_summary = Top_User_df.groupby("State")["Registered_Users"].sum().reset_index()

# Fix inconsistent naming for better GeoJSON matching
state_user_summary["State"] = state_user_summary["State"].str.title()

# Preview the data (optional)
print(state_user_summary.head())

# Plotting the choropleth map
fig = px.choropleth(
    state_user_summary,
    geojson=india_states_geojson,
    featureidkey="properties.ST_NM",
    locations="State",
    color="Registered_Users",
    color_continuous_scale="Blues",
    title="Total Registered Users by State - PhonePe Pulse"
)

fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0})
fig.show()
